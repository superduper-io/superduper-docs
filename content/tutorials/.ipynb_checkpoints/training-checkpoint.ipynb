# %% [markdown]
# # Training and Managing MNIST Predictions with

# %% [markdown]
# ## Introduction
#
# This notebook guides you through the implementation of a classic machine learning task: MNIST handwritten digit recognition. The twist? We perform the task directly on data hosted in a database using .
#
# This example makes it easy to connect any of your image recognition model directly to your database in real-time. With , you can skip complicated MLOps pipelines. It's a new straightforward way to integrate your AI model with your data, ensuring simplicity, efficiency and speed.

# %%
# !pip install torch torchvision

# %% [markdown]
# ## Connect to datastore
#
# First, we need to establish a connection to a MongoDB datastore via .

# %%
from superduper import superduper
    
db = superduper('mongomock://')
# Out:
# 2024-May-24 16:37:45.46| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.base.build:69   | Data Client is ready. mongomock.MongoClient('localhost', 27017)
# 2024-May-24 16:37:45.48| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.base.build:42   | Connecting to Metadata Client with engine:  mongomock.MongoClient('localhost', 27017)
# 2024-May-24 16:37:45.48| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.base.build:155  | Connecting to compute client: None
# 2024-May-24 16:37:45.48| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.base.datalayer:85   | Building Data Layer
# 2024-May-24 16:37:45.48| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.base.build:220  | Configuration:
#  +---------------+--------------+
# | Configuration |    Value     |
# +---------------+--------------+
# |  Data Backend | mongomock:// |
# +---------------+--------------+

# %% [markdown]
# ## Load Dataset
#
# After establishing a connection to MongoDB, the next step is to load the MNIST dataset. 's strength lies in handling diverse data types, especially those that are challenging. To achieve this, we use an `Encoder` in conjunction with `Document` wrappers. These components allow Python dictionaries containing non-JSONable or bytes objects to be seamlessly inserted into the underlying data infrastructure.

# %%
import torchvision
from superduper import Document

import random

# Load MNIST images as Python objects using the Python Imaging Library.
# Each MNIST item is a tuple (image, label)
mnist_data = list(torchvision.datasets.MNIST(root='./data', download=True))

document_list = [Document({'img': x[0], 'class': x[1]}) for x in mnist_data]

# Shuffle the data and select a subset of 1000 documents
random.shuffle(document_list)
data = document_list[:1000]

# Insert the selected data into the mnist_collection which we mentioned before like: mnist_collection = Collection('mnist')
db['mnist'].insert_many(data[:-100]).execute()
# Out:
# 2024-May-24 16:38:37.10| WARNING  | Duncans-MacBook-Pro.fritz.box| superduper.misc.annotations:117  | add is deprecated and will be removed in a future release.
# 2024-May-24 16:38:37.10| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:386  | Initializing DataType : dill
# 2024-May-24 16:38:37.10| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:389  | Initialized  DataType : dill successfully
# 2024-May-24 16:38:37.10| WARNING  | Duncans-MacBook-Pro.fritz.box| superduper.backends.local.artifacts:82   | File /tmp/e6eb888f0b0fbbab905029cb309537b9383919a6 already exists
# 2024-May-24 16:38:37.10| WARNING  | Duncans-MacBook-Pro.fritz.box| superduper.backends.local.artifacts:82   | File /tmp/ee1a946181f065af29a3c8637b2858b153d8fc8e already exists
# 2024-May-24 16:38:37.10| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:386  | Initializing DataType : pil_image
# 2024-May-24 16:38:37.10| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:389  | Initialized  DataType : pil_image successfully
# 2024-May-24 16:38:37.25| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.backends.local.compute:37   | Submitting job. function:<function callable_job at 0x10c3fdc60>
# 2024-May-24 16:38:37.37| SUCCESS  | Duncans-MacBook-Pro.fritz.box| superduper.backends.local.compute:43   | Job submitted on <superduper.backends.local.compute.LocalComputeBackend object at 0x14df63ad0>.  function:<function callable_job at 0x10c3fdc60> future:2f72fdb5-89d1-41ab-90ed-1cdcb4447d6b
# ([ObjectId('6650a66d459b3818bfd78e41'),
#   ObjectId('6650a66d459b3818bfd78e42'),
#   ObjectId('6650a66d459b3818bfd78e43'),
#   ObjectId('6650a66d459b3818bfd78e44'),
#   ObjectId('6650a66d459b3818bfd78e45'),
#   ObjectId('6650a66d459b3818bfd78e46'),
#   ObjectId('6650a66d459b3818bfd78e47'),
#   ObjectId('6650a66d459b3818bfd78e48'),
#   ObjectId('6650a66d459b3818bfd78e49'),
#   ObjectId('6650a66d459b3818bfd78e4a'),
#   ObjectId('6650a66d459b3818bfd78e4b'),
#   ObjectId('6650a66d459b3818bfd78e4c'),
#   ObjectId('6650a66d459b3818bfd78e4d'),
#   ObjectId('6650a66d459b3818bfd78e4e'),
#   ObjectId('6650a66d459b3818bfd78e4f'),
#   ObjectId('6650a66d459b3818bfd78e50'),
#   ObjectId('6650a66d459b3818bfd78e51'),
#   ObjectId('6650a66d459b3818bfd78e52'),
#   ObjectId('6650a66d459b3818bfd78e53'),
#   ObjectId('6650a66d459b3818bfd78e54'),
#   ObjectId('6650a66d459b3818bfd78e55'),
#   ObjectId('6650a66d459b3818bfd78e56'),
#   ObjectId('6650a66d459b3818bfd78e57'),
#   ObjectId('6650a66d459b3818bfd78e58'),
#   ObjectId('6650a66d459b3818bfd78e59'),
#   ObjectId('6650a66d459b3818bfd78e5a'),
#   ObjectId('6650a66d459b3818bfd78e5b'),
#   ObjectId('6650a66d459b3818bfd78e5c'),
#   ObjectId('6650a66d459b3818bfd78e5d'),
#   ObjectId('6650a66d459b3818bfd78e5e'),
#   ObjectId('6650a66d459b3818bfd78e5f'),
#   ObjectId('6650a66d459b3818bfd78e60'),
#   ObjectId('6650a66d459b3818bfd78e61'),
#   ObjectId('6650a66d459b3818bfd78e62'),
#   ObjectId('6650a66d459b3818bfd78e63'),
#   ObjectId('6650a66d459b3818bfd78e64'),
#   ObjectId('6650a66d459b3818bfd78e65'),
#   ObjectId('6650a66d459b3818bfd78e66'),
#   ObjectId('6650a66d459b3818bfd78e67'),
#   ObjectId('6650a66d459b3818bfd78e68'),
#   ObjectId('6650a66d459b3818bfd78e69'),
#   ObjectId('6650a66d459b3818bfd78e6a'),
#   ObjectId('6650a66d459b3818bfd78e6b'),
#   ObjectId('6650a66d459b3818bfd78e6c'),
#   ObjectId('6650a66d459b3818bfd78e6d'),
#   ObjectId('6650a66d459b3818bfd78e6e'),
#   ObjectId('6650a66d459b3818bfd78e6f'),
#   ObjectId('6650a66d459b3818bfd78e70'),
#   ObjectId('6650a66d459b3818bfd78e71'),
#   ObjectId('6650a66d459b3818bfd78e72'),
#   ObjectId('6650a66d459b3818bfd78e73'),
#   ObjectId('6650a66d459b3818bfd78e74'),
#   ObjectId('6650a66d459b3818bfd78e75'),
#   ObjectId('6650a66d459b3818bfd78e76'),
#   ObjectId('6650a66d459b3818bfd78e77'),
#   ObjectId('6650a66d459b3818bfd78e78'),
#   ObjectId('6650a66d459b3818bfd78e79'),
#   ObjectId('6650a66d459b3818bfd78e7a'),
#   ObjectId('6650a66d459b3818bfd78e7b'),
#   ObjectId('6650a66d459b3818bfd78e7c'),
#   ObjectId('6650a66d459b3818bfd78e7d'),
#   ObjectId('6650a66d459b3818bfd78e7e'),
#   ObjectId('6650a66d459b3818bfd78e7f'),
#   ObjectId('6650a66d459b3818bfd78e80'),
#   ObjectId('6650a66d459b3818bfd78e81'),
#   ObjectId('6650a66d459b3818bfd78e82'),
#   ObjectId('6650a66d459b3818bfd78e83'),
#   ObjectId('6650a66d459b3818bfd78e84'),
#   ObjectId('6650a66d459b3818bfd78e85'),
#   ObjectId('6650a66d459b3818bfd78e86'),
#   ObjectId('6650a66d459b3818bfd78e87'),
#   ObjectId('6650a66d459b3818bfd78e88'),
#   ObjectId('6650a66d459b3818bfd78e89'),
#   ObjectId('6650a66d459b3818bfd78e8a'),
#   ObjectId('6650a66d459b3818bfd78e8b'),
#   ObjectId('6650a66d459b3818bfd78e8c'),
#   ObjectId('6650a66d459b3818bfd78e8d'),
#   ObjectId('6650a66d459b3818bfd78e8e'),
#   ObjectId('6650a66d459b3818bfd78e8f'),
#   ObjectId('6650a66d459b3818bfd78e90'),
#   ObjectId('6650a66d459b3818bfd78e91'),
#   ObjectId('6650a66d459b3818bfd78e92'),
#   ObjectId('6650a66d459b3818bfd78e93'),
#   ObjectId('6650a66d459b3818bfd78e94'),
#   ObjectId('6650a66d459b3818bfd78e95'),
#   ObjectId('6650a66d459b3818bfd78e96'),
#   ObjectId('6650a66d459b3818bfd78e97'),
#   ObjectId('6650a66d459b3818bfd78e98'),
#   ObjectId('6650a66d459b3818bfd78e99'),
#   ObjectId('6650a66d459b3818bfd78e9a'),
#   ObjectId('6650a66d459b3818bfd78e9b'),
#   ObjectId('6650a66d459b3818bfd78e9c'),
#   ObjectId('6650a66d459b3818bfd78e9d'),
#   ObjectId('6650a66d459b3818bfd78e9e'),
#   ObjectId('6650a66d459b3818bfd78e9f'),
#   ObjectId('6650a66d459b3818bfd78ea0'),
#   ObjectId('6650a66d459b3818bfd78ea1'),
#   ObjectId('6650a66d459b3818bfd78ea2'),
#   ObjectId('6650a66d459b3818bfd78ea3'),
#   ObjectId('6650a66d459b3818bfd78ea4'),
#   ObjectId('6650a66d459b3818bfd78ea5'),
#   ObjectId('6650a66d459b3818bfd78ea6'),
#   ObjectId('6650a66d459b3818bfd78ea7'),
#   ObjectId('6650a66d459b3818bfd78ea8'),
#   ObjectId('6650a66d459b3818bfd78ea9'),
#   ObjectId('6650a66d459b3818bfd78eaa'),
#   ObjectId('6650a66d459b3818bfd78eab'),
#   ObjectId('6650a66d459b3818bfd78eac'),
#   ObjectId('6650a66d459b3818bfd78ead'),
#   ObjectId('6650a66d459b3818bfd78eae'),
#   ObjectId('6650a66d459b3818bfd78eaf'),
#   ObjectId('6650a66d459b3818bfd78eb0'),
#   ObjectId('6650a66d459b3818bfd78eb1'),
#   ObjectId('6650a66d459b3818bfd78eb2'),
#   ObjectId('6650a66d459b3818bfd78eb3'),
#   ObjectId('6650a66d459b3818bfd78eb4'),
#   ObjectId('6650a66d459b3818bfd78eb5'),
#   ObjectId('6650a66d459b3818bfd78eb6'),
#   ObjectId('6650a66d459b3818bfd78eb7'),
#   ObjectId('6650a66d459b3818bfd78eb8'),
#   ObjectId('6650a66d459b3818bfd78eb9'),
#   ObjectId('6650a66d459b3818bfd78eba'),
#   ObjectId('6650a66d459b3818bfd78ebb'),
#   ObjectId('6650a66d459b3818bfd78ebc'),
#   ObjectId('6650a66d459b3818bfd78ebd'),
#   ObjectId('6650a66d459b3818bfd78ebe'),
#   ObjectId('6650a66d459b3818bfd78ebf'),
#   ObjectId('6650a66d459b3818bfd78ec0'),
#   ObjectId('6650a66d459b3818bfd78ec1'),
#   ObjectId('6650a66d459b3818bfd78ec2'),
#   ObjectId('6650a66d459b3818bfd78ec3'),
#   ObjectId('6650a66d459b3818bfd78ec4'),
#   ObjectId('6650a66d459b3818bfd78ec5'),
#   ObjectId('6650a66d459b3818bfd78ec6'),
#   ObjectId('6650a66d459b3818bfd78ec7'),
#   ObjectId('6650a66d459b3818bfd78ec8'),
#   ObjectId('6650a66d459b3818bfd78ec9'),
#   ObjectId('6650a66d459b3818bfd78eca'),
#   ObjectId('6650a66d459b3818bfd78ecb'),
#   ObjectId('6650a66d459b3818bfd78ecc'),
#   ObjectId('6650a66d459b3818bfd78ecd'),
#   ObjectId('6650a66d459b3818bfd78ece'),
#   ObjectId('6650a66d459b3818bfd78ecf'),
#   ObjectId('6650a66d459b3818bfd78ed0'),
#   ObjectId('6650a66d459b3818bfd78ed1'),
#   ObjectId('6650a66d459b3818bfd78ed2'),
#   ObjectId('6650a66d459b3818bfd78ed3'),
#   ObjectId('6650a66d459b3818bfd78ed4'),
#   ObjectId('6650a66d459b3818bfd78ed5'),
#   ObjectId('6650a66d459b3818bfd78ed6'),
#   ObjectId('6650a66d459b3818bfd78ed7'),
#   ObjectId('6650a66d459b3818bfd78ed8'),
#   ObjectId('6650a66d459b3818bfd78ed9'),
#   ObjectId('6650a66d459b3818bfd78eda'),
#   ObjectId('6650a66d459b3818bfd78edb'),
#   ObjectId('6650a66d459b3818bfd78edc'),
#   ObjectId('6650a66d459b3818bfd78edd'),
#   ObjectId('6650a66d459b3818bfd78ede'),
#   ObjectId('6650a66d459b3818bfd78edf'),
#   ObjectId('6650a66d459b3818bfd78ee0'),
#   ObjectId('6650a66d459b3818bfd78ee1'),
#   ObjectId('6650a66d459b3818bfd78ee2'),
#   ObjectId('6650a66d459b3818bfd78ee3'),
#   ObjectId('6650a66d459b3818bfd78ee4'),
#   ObjectId('6650a66d459b3818bfd78ee5'),
#   ObjectId('6650a66d459b3818bfd78ee6'),
#   ObjectId('6650a66d459b3818bfd78ee7'),
#   ObjectId('6650a66d459b3818bfd78ee8'),
#   ObjectId('6650a66d459b3818bfd78ee9'),
#   ObjectId('6650a66d459b3818bfd78eea'),
#   ObjectId('6650a66d459b3818bfd78eeb'),
#   ObjectId('6650a66d459b3818bfd78eec'),
#   ObjectId('6650a66d459b3818bfd78eed'),
#   ObjectId('6650a66d459b3818bfd78eee'),
#   ObjectId('6650a66d459b3818bfd78eef'),
#   ObjectId('6650a66d459b3818bfd78ef0'),
#   ObjectId('6650a66d459b3818bfd78ef1'),
#   ObjectId('6650a66d459b3818bfd78ef2'),
#   ObjectId('6650a66d459b3818bfd78ef3'),
#   ObjectId('6650a66d459b3818bfd78ef4'),
#   ObjectId('6650a66d459b3818bfd78ef5'),
#   ObjectId('6650a66d459b3818bfd78ef6'),
#   ObjectId('6650a66d459b3818bfd78ef7'),
#   ObjectId('6650a66d459b3818bfd78ef8'),
#   ObjectId('6650a66d459b3818bfd78ef9'),
#   ObjectId('6650a66d459b3818bfd78efa'),
#   ObjectId('6650a66d459b3818bfd78efb'),
#   ObjectId('6650a66d459b3818bfd78efc'),
#   ObjectId('6650a66d459b3818bfd78efd'),
#   ObjectId('6650a66d459b3818bfd78efe'),
#   ObjectId('6650a66d459b3818bfd78eff'),
#   ObjectId('6650a66d459b3818bfd78f00'),
#   ObjectId('6650a66d459b3818bfd78f01'),
#   ObjectId('6650a66d459b3818bfd78f02'),
#   ObjectId('6650a66d459b3818bfd78f03'),
#   ObjectId('6650a66d459b3818bfd78f04'),
#   ObjectId('6650a66d459b3818bfd78f05'),
#   ObjectId('6650a66d459b3818bfd78f06'),
#   ObjectId('6650a66d459b3818bfd78f07'),
#   ObjectId('6650a66d459b3818bfd78f08'),
#   ObjectId('6650a66d459b3818bfd78f09'),
#   ObjectId('6650a66d459b3818bfd78f0a'),
#   ObjectId('6650a66d459b3818bfd78f0b'),
#   ObjectId('6650a66d459b3818bfd78f0c'),
#   ObjectId('6650a66d459b3818bfd78f0d'),
#   ObjectId('6650a66d459b3818bfd78f0e'),
#   ObjectId('6650a66d459b3818bfd78f0f'),
#   ObjectId('6650a66d459b3818bfd78f10'),
#   ObjectId('6650a66d459b3818bfd78f11'),
#   ObjectId('6650a66d459b3818bfd78f12'),
#   ObjectId('6650a66d459b3818bfd78f13'),
#   ObjectId('6650a66d459b3818bfd78f14'),
#   ObjectId('6650a66d459b3818bfd78f15'),
#   ObjectId('6650a66d459b3818bfd78f16'),
#   ObjectId('6650a66d459b3818bfd78f17'),
#   ObjectId('6650a66d459b3818bfd78f18'),
#   ObjectId('6650a66d459b3818bfd78f19'),
#   ObjectId('6650a66d459b3818bfd78f1a'),
#   ObjectId('6650a66d459b3818bfd78f1b'),
#   ObjectId('6650a66d459b3818bfd78f1c'),
#   ObjectId('6650a66d459b3818bfd78f1d'),
#   ObjectId('6650a66d459b3818bfd78f1e'),
#   ObjectId('6650a66d459b3818bfd78f1f'),
#   ObjectId('6650a66d459b3818bfd78f20'),
#   ObjectId('6650a66d459b3818bfd78f21'),
#   ObjectId('6650a66d459b3818bfd78f22'),
#   ObjectId('6650a66d459b3818bfd78f23'),
#   ObjectId('6650a66d459b3818bfd78f24'),
#   ObjectId('6650a66d459b3818bfd78f25'),
#   ObjectId('6650a66d459b3818bfd78f26'),
#   ObjectId('6650a66d459b3818bfd78f27'),
#   ObjectId('6650a66d459b3818bfd78f28'),
#   ObjectId('6650a66d459b3818bfd78f29'),
#   ObjectId('6650a66d459b3818bfd78f2a'),
#   ObjectId('6650a66d459b3818bfd78f2b'),
#   ObjectId('6650a66d459b3818bfd78f2c'),
#   ObjectId('6650a66d459b3818bfd78f2d'),
#   ObjectId('6650a66d459b3818bfd78f2e'),
#   ObjectId('6650a66d459b3818bfd78f2f'),
#   ObjectId('6650a66d459b3818bfd78f30'),
#   ObjectId('6650a66d459b3818bfd78f31'),
#   ObjectId('6650a66d459b3818bfd78f32'),
#   ObjectId('6650a66d459b3818bfd78f33'),
#   ObjectId('6650a66d459b3818bfd78f34'),
#   ObjectId('6650a66d459b3818bfd78f35'),
#   ObjectId('6650a66d459b3818bfd78f36'),
#   ObjectId('6650a66d459b3818bfd78f37'),
#   ObjectId('6650a66d459b3818bfd78f38'),
#   ObjectId('6650a66d459b3818bfd78f39'),
#   ObjectId('6650a66d459b3818bfd78f3a'),
#   ObjectId('6650a66d459b3818bfd78f3b'),
#   ObjectId('6650a66d459b3818bfd78f3c'),
#   ObjectId('6650a66d459b3818bfd78f3d'),
#   ObjectId('6650a66d459b3818bfd78f3e'),
#   ObjectId('6650a66d459b3818bfd78f3f'),
#   ObjectId('6650a66d459b3818bfd78f40'),
#   ObjectId('6650a66d459b3818bfd78f41'),
#   ObjectId('6650a66d459b3818bfd78f42'),
#   ObjectId('6650a66d459b3818bfd78f43'),
#   ObjectId('6650a66d459b3818bfd78f44'),
#   ObjectId('6650a66d459b3818bfd78f45'),
#   ObjectId('6650a66d459b3818bfd78f46'),
#   ObjectId('6650a66d459b3818bfd78f47'),
#   ObjectId('6650a66d459b3818bfd78f48'),
#   ObjectId('6650a66d459b3818bfd78f49'),
#   ObjectId('6650a66d459b3818bfd78f4a'),
#   ObjectId('6650a66d459b3818bfd78f4b'),
#   ObjectId('6650a66d459b3818bfd78f4c'),
#   ObjectId('6650a66d459b3818bfd78f4d'),
#   ObjectId('6650a66d459b3818bfd78f4e'),
#   ObjectId('6650a66d459b3818bfd78f4f'),
#   ObjectId('6650a66d459b3818bfd78f50'),
#   ObjectId('6650a66d459b3818bfd78f51'),
#   ObjectId('6650a66d459b3818bfd78f52'),
#   ObjectId('6650a66d459b3818bfd78f53'),
#   ObjectId('6650a66d459b3818bfd78f54'),
#   ObjectId('6650a66d459b3818bfd78f55'),
#   ObjectId('6650a66d459b3818bfd78f56'),
#   ObjectId('6650a66d459b3818bfd78f57'),
#   ObjectId('6650a66d459b3818bfd78f58'),
#   ObjectId('6650a66d459b3818bfd78f59'),
#   ObjectId('6650a66d459b3818bfd78f5a'),
#   ObjectId('6650a66d459b3818bfd78f5b'),
#   ObjectId('6650a66d459b3818bfd78f5c'),
#   ObjectId('6650a66d459b3818bfd78f5d'),
#   ObjectId('6650a66d459b3818bfd78f5e'),
#   ObjectId('6650a66d459b3818bfd78f5f'),
#   ObjectId('6650a66d459b3818bfd78f60'),
#   ObjectId('6650a66d459b3818bfd78f61'),
#   ObjectId('6650a66d459b3818bfd78f62'),
#   ObjectId('6650a66d459b3818bfd78f63'),
#   ObjectId('6650a66d459b3818bfd78f64'),
#   ObjectId('6650a66d459b3818bfd78f65'),
#   ObjectId('6650a66d459b3818bfd78f66'),
#   ObjectId('6650a66d459b3818bfd78f67'),
#   ObjectId('6650a66d459b3818bfd78f68'),
#   ObjectId('6650a66d459b3818bfd78f69'),
#   ObjectId('6650a66d459b3818bfd78f6a'),
#   ObjectId('6650a66d459b3818bfd78f6b'),
#   ObjectId('6650a66d459b3818bfd78f6c'),
#   ObjectId('6650a66d459b3818bfd78f6d'),
#   ObjectId('6650a66d459b3818bfd78f6e'),
#   ObjectId('6650a66d459b3818bfd78f6f'),
#   ObjectId('6650a66d459b3818bfd78f70'),
#   ObjectId('6650a66d459b3818bfd78f71'),
#   ObjectId('6650a66d459b3818bfd78f72'),
#   ObjectId('6650a66d459b3818bfd78f73'),
#   ObjectId('6650a66d459b3818bfd78f74'),
#   ObjectId('6650a66d459b3818bfd78f75'),
#   ObjectId('6650a66d459b3818bfd78f76'),
#   ObjectId('6650a66d459b3818bfd78f77'),
#   ObjectId('6650a66d459b3818bfd78f78'),
#   ObjectId('6650a66d459b3818bfd78f79'),
#   ObjectId('6650a66d459b3818bfd78f7a'),
#   ObjectId('6650a66d459b3818bfd78f7b'),
#   ObjectId('6650a66d459b3818bfd78f7c'),
#   ObjectId('6650a66d459b3818bfd78f7d'),
#   ObjectId('6650a66d459b3818bfd78f7e'),
#   ObjectId('6650a66d459b3818bfd78f7f'),
#   ObjectId('6650a66d459b3818bfd78f80'),
#   ObjectId('6650a66d459b3818bfd78f81'),
#   ObjectId('6650a66d459b3818bfd78f82'),
#   ObjectId('6650a66d459b3818bfd78f83'),
#   ObjectId('6650a66d459b3818bfd78f84'),
#   ObjectId('6650a66d459b3818bfd78f85'),
#   ObjectId('6650a66d459b3818bfd78f86'),
#   ObjectId('6650a66d459b3818bfd78f87'),
#   ObjectId('6650a66d459b3818bfd78f88'),
#   ObjectId('6650a66d459b3818bfd78f89'),
#   ObjectId('6650a66d459b3818bfd78f8a'),
#   ObjectId('6650a66d459b3818bfd78f8b'),
#   ObjectId('6650a66d459b3818bfd78f8c'),
#   ObjectId('6650a66d459b3818bfd78f8d'),
#   ObjectId('6650a66d459b3818bfd78f8e'),
#   ObjectId('6650a66d459b3818bfd78f8f'),
#   ObjectId('6650a66d459b3818bfd78f90'),
#   ObjectId('6650a66d459b3818bfd78f91'),
#   ObjectId('6650a66d459b3818bfd78f92'),
#   ObjectId('6650a66d459b3818bfd78f93'),
#   ObjectId('6650a66d459b3818bfd78f94'),
#   ObjectId('6650a66d459b3818bfd78f95'),
#   ObjectId('6650a66d459b3818bfd78f96'),
#   ObjectId('6650a66d459b3818bfd78f97'),
#   ObjectId('6650a66d459b3818bfd78f98'),
#   ObjectId('6650a66d459b3818bfd78f99'),
#   ObjectId('6650a66d459b3818bfd78f9a'),
#   ObjectId('6650a66d459b3818bfd78f9b'),
#   ObjectId('6650a66d459b3818bfd78f9c'),
#   ObjectId('6650a66d459b3818bfd78f9d'),
#   ObjectId('6650a66d459b3818bfd78f9e'),
#   ObjectId('6650a66d459b3818bfd78f9f'),
#   ObjectId('6650a66d459b3818bfd78fa0'),
#   ObjectId('6650a66d459b3818bfd78fa1'),
#   ObjectId('6650a66d459b3818bfd78fa2'),
#   ObjectId('6650a66d459b3818bfd78fa3'),
#   ObjectId('6650a66d459b3818bfd78fa4'),
#   ObjectId('6650a66d459b3818bfd78fa5'),
#   ObjectId('6650a66d459b3818bfd78fa6'),
#   ObjectId('6650a66d459b3818bfd78fa7'),
#   ObjectId('6650a66d459b3818bfd78fa8'),
#   ObjectId('6650a66d459b3818bfd78fa9'),
#   ObjectId('6650a66d459b3818bfd78faa'),
#   ObjectId('6650a66d459b3818bfd78fab'),
#   ObjectId('6650a66d459b3818bfd78fac'),
#   ObjectId('6650a66d459b3818bfd78fad'),
#   ObjectId('6650a66d459b3818bfd78fae'),
#   ObjectId('6650a66d459b3818bfd78faf'),
#   ObjectId('6650a66d459b3818bfd78fb0'),
#   ObjectId('6650a66d459b3818bfd78fb1'),
#   ObjectId('6650a66d459b3818bfd78fb2'),
#   ObjectId('6650a66d459b3818bfd78fb3'),
#   ObjectId('6650a66d459b3818bfd78fb4'),
#   ObjectId('6650a66d459b3818bfd78fb5'),
#   ObjectId('6650a66d459b3818bfd78fb6'),
#   ObjectId('6650a66d459b3818bfd78fb7'),
#   ObjectId('6650a66d459b3818bfd78fb8'),
#   ObjectId('6650a66d459b3818bfd78fb9'),
#   ObjectId('6650a66d459b3818bfd78fba'),
#   ObjectId('6650a66d459b3818bfd78fbb'),
#   ObjectId('6650a66d459b3818bfd78fbc'),
#   ObjectId('6650a66d459b3818bfd78fbd'),
#   ObjectId('6650a66d459b3818bfd78fbe'),
#   ObjectId('6650a66d459b3818bfd78fbf'),
#   ObjectId('6650a66d459b3818bfd78fc0'),
#   ObjectId('6650a66d459b3818bfd78fc1'),
#   ObjectId('6650a66d459b3818bfd78fc2'),
#   ObjectId('6650a66d459b3818bfd78fc3'),
#   ObjectId('6650a66d459b3818bfd78fc4'),
#   ObjectId('6650a66d459b3818bfd78fc5'),
#   ObjectId('6650a66d459b3818bfd78fc6'),
#   ObjectId('6650a66d459b3818bfd78fc7'),
#   ObjectId('6650a66d459b3818bfd78fc8'),
#   ObjectId('6650a66d459b3818bfd78fc9'),
#   ObjectId('6650a66d459b3818bfd78fca'),
#   ObjectId('6650a66d459b3818bfd78fcb'),
#   ObjectId('6650a66d459b3818bfd78fcc'),
#   ObjectId('6650a66d459b3818bfd78fcd'),
#   ObjectId('6650a66d459b3818bfd78fce'),
#   ObjectId('6650a66d459b3818bfd78fcf'),
#   ObjectId('6650a66d459b3818bfd78fd0'),
#   ObjectId('6650a66d459b3818bfd78fd1'),
#   ObjectId('6650a66d459b3818bfd78fd2'),
#   ObjectId('6650a66d459b3818bfd78fd3'),
#   ObjectId('6650a66d459b3818bfd78fd4'),
#   ObjectId('6650a66d459b3818bfd78fd5'),
#   ObjectId('6650a66d459b3818bfd78fd6'),
#   ObjectId('6650a66d459b3818bfd78fd7'),
#   ObjectId('6650a66d459b3818bfd78fd8'),
#   ObjectId('6650a66d459b3818bfd78fd9'),
#   ObjectId('6650a66d459b3818bfd78fda'),
#   ObjectId('6650a66d459b3818bfd78fdb'),
#   ObjectId('6650a66d459b3818bfd78fdc'),
#   ObjectId('6650a66d459b3818bfd78fdd'),
#   ObjectId('6650a66d459b3818bfd78fde'),
#   ObjectId('6650a66d459b3818bfd78fdf'),
#   ObjectId('6650a66d459b3818bfd78fe0'),
#   ObjectId('6650a66d459b3818bfd78fe1'),
#   ObjectId('6650a66d459b3818bfd78fe2'),
#   ObjectId('6650a66d459b3818bfd78fe3'),
#   ObjectId('6650a66d459b3818bfd78fe4'),
#   ObjectId('6650a66d459b3818bfd78fe5'),
#   ObjectId('6650a66d459b3818bfd78fe6'),
#   ObjectId('6650a66d459b3818bfd78fe7'),
#   ObjectId('6650a66d459b3818bfd78fe8'),
#   ObjectId('6650a66d459b3818bfd78fe9'),
#   ObjectId('6650a66d459b3818bfd78fea'),
#   ObjectId('6650a66d459b3818bfd78feb'),
#   ObjectId('6650a66d459b3818bfd78fec'),
#   ObjectId('6650a66d459b3818bfd78fed'),
#   ObjectId('6650a66d459b3818bfd78fee'),
#   ObjectId('6650a66d459b3818bfd78fef'),
#   ObjectId('6650a66d459b3818bfd78ff0'),
#   ObjectId('6650a66d459b3818bfd78ff1'),
#   ObjectId('6650a66d459b3818bfd78ff2'),
#   ObjectId('6650a66d459b3818bfd78ff3'),
#   ObjectId('6650a66d459b3818bfd78ff4'),
#   ObjectId('6650a66d459b3818bfd78ff5'),
#   ObjectId('6650a66d459b3818bfd78ff6'),
#   ObjectId('6650a66d459b3818bfd78ff7'),
#   ObjectId('6650a66d459b3818bfd78ff8'),
#   ObjectId('6650a66d459b3818bfd78ff9'),
#   ObjectId('6650a66d459b3818bfd78ffa'),
#   ObjectId('6650a66d459b3818bfd78ffb'),
#   ObjectId('6650a66d459b3818bfd78ffc'),
#   ObjectId('6650a66d459b3818bfd78ffd'),
#   ObjectId('6650a66d459b3818bfd78ffe'),
#   ObjectId('6650a66d459b3818bfd78fff'),
#   ObjectId('6650a66d459b3818bfd79000'),
#   ObjectId('6650a66d459b3818bfd79001'),
#   ObjectId('6650a66d459b3818bfd79002'),
#   ObjectId('6650a66d459b3818bfd79003'),
#   ObjectId('6650a66d459b3818bfd79004'),
#   ObjectId('6650a66d459b3818bfd79005'),
#   ObjectId('6650a66d459b3818bfd79006'),
#   ObjectId('6650a66d459b3818bfd79007'),
#   ObjectId('6650a66d459b3818bfd79008'),
#   ObjectId('6650a66d459b3818bfd79009'),
#   ObjectId('6650a66d459b3818bfd7900a'),
#   ObjectId('6650a66d459b3818bfd7900b'),
#   ObjectId('6650a66d459b3818bfd7900c'),
#   ObjectId('6650a66d459b3818bfd7900d'),
#   ObjectId('6650a66d459b3818bfd7900e'),
#   ObjectId('6650a66d459b3818bfd7900f'),
#   ObjectId('6650a66d459b3818bfd79010'),
#   ObjectId('6650a66d459b3818bfd79011'),
#   ObjectId('6650a66d459b3818bfd79012'),
#   ObjectId('6650a66d459b3818bfd79013'),
#   ObjectId('6650a66d459b3818bfd79014'),
#   ObjectId('6650a66d459b3818bfd79015'),
#   ObjectId('6650a66d459b3818bfd79016'),
#   ObjectId('6650a66d459b3818bfd79017'),
#   ObjectId('6650a66d459b3818bfd79018'),
#   ObjectId('6650a66d459b3818bfd79019'),
#   ObjectId('6650a66d459b3818bfd7901a'),
#   ObjectId('6650a66d459b3818bfd7901b'),
#   ObjectId('6650a66d459b3818bfd7901c'),
#   ObjectId('6650a66d459b3818bfd7901d'),
#   ObjectId('6650a66d459b3818bfd7901e'),
#   ObjectId('6650a66d459b3818bfd7901f'),
#   ObjectId('6650a66d459b3818bfd79020'),
#   ObjectId('6650a66d459b3818bfd79021'),
#   ObjectId('6650a66d459b3818bfd79022'),
#   ObjectId('6650a66d459b3818bfd79023'),
#   ObjectId('6650a66d459b3818bfd79024'),
#   ObjectId('6650a66d459b3818bfd79025'),
#   ObjectId('6650a66d459b3818bfd79026'),
#   ObjectId('6650a66d459b3818bfd79027'),
#   ObjectId('6650a66d459b3818bfd79028'),
#   ObjectId('6650a66d459b3818bfd79029'),
#   ObjectId('6650a66d459b3818bfd7902a'),
#   ObjectId('6650a66d459b3818bfd7902b'),
#   ObjectId('6650a66d459b3818bfd7902c'),
#   ObjectId('6650a66d459b3818bfd7902d'),
#   ObjectId('6650a66d459b3818bfd7902e'),
#   ObjectId('6650a66d459b3818bfd7902f'),
#   ObjectId('6650a66d459b3818bfd79030'),
#   ObjectId('6650a66d459b3818bfd79031'),
#   ObjectId('6650a66d459b3818bfd79032'),
#   ObjectId('6650a66d459b3818bfd79033'),
#   ObjectId('6650a66d459b3818bfd79034'),
#   ObjectId('6650a66d459b3818bfd79035'),
#   ObjectId('6650a66d459b3818bfd79036'),
#   ObjectId('6650a66d459b3818bfd79037'),
#   ObjectId('6650a66d459b3818bfd79038'),
#   ObjectId('6650a66d459b3818bfd79039'),
#   ObjectId('6650a66d459b3818bfd7903a'),
#   ObjectId('6650a66d459b3818bfd7903b'),
#   ObjectId('6650a66d459b3818bfd7903c'),
#   ObjectId('6650a66d459b3818bfd7903d'),
#   ObjectId('6650a66d459b3818bfd7903e'),
#   ObjectId('6650a66d459b3818bfd7903f'),
#   ObjectId('6650a66d459b3818bfd79040'),
#   ObjectId('6650a66d459b3818bfd79041'),
#   ObjectId('6650a66d459b3818bfd79042'),
#   ObjectId('6650a66d459b3818bfd79043'),
#   ObjectId('6650a66d459b3818bfd79044'),
#   ObjectId('6650a66d459b3818bfd79045'),
#   ObjectId('6650a66d459b3818bfd79046'),
#   ObjectId('6650a66d459b3818bfd79047'),
#   ObjectId('6650a66d459b3818bfd79048'),
#   ObjectId('6650a66d459b3818bfd79049'),
#   ObjectId('6650a66d459b3818bfd7904a'),
#   ObjectId('6650a66d459b3818bfd7904b'),
#   ObjectId('6650a66d459b3818bfd7904c'),
#   ObjectId('6650a66d459b3818bfd7904d'),
#   ObjectId('6650a66d459b3818bfd7904e'),
#   ObjectId('6650a66d459b3818bfd7904f'),
#   ObjectId('6650a66d459b3818bfd79050'),
#   ObjectId('6650a66d459b3818bfd79051'),
#   ObjectId('6650a66d459b3818bfd79052'),
#   ObjectId('6650a66d459b3818bfd79053'),
#   ObjectId('6650a66d459b3818bfd79054'),
#   ObjectId('6650a66d459b3818bfd79055'),
#   ObjectId('6650a66d459b3818bfd79056'),
#   ObjectId('6650a66d459b3818bfd79057'),
#   ObjectId('6650a66d459b3818bfd79058'),
#   ObjectId('6650a66d459b3818bfd79059'),
#   ObjectId('6650a66d459b3818bfd7905a'),
#   ObjectId('6650a66d459b3818bfd7905b'),
#   ObjectId('6650a66d459b3818bfd7905c'),
#   ObjectId('6650a66d459b3818bfd7905d'),
#   ObjectId('6650a66d459b3818bfd7905e'),
#   ObjectId('6650a66d459b3818bfd7905f'),
#   ObjectId('6650a66d459b3818bfd79060'),
#   ObjectId('6650a66d459b3818bfd79061'),
#   ObjectId('6650a66d459b3818bfd79062'),
#   ObjectId('6650a66d459b3818bfd79063'),
#   ObjectId('6650a66d459b3818bfd79064'),
#   ObjectId('6650a66d459b3818bfd79065'),
#   ObjectId('6650a66d459b3818bfd79066'),
#   ObjectId('6650a66d459b3818bfd79067'),
#   ObjectId('6650a66d459b3818bfd79068'),
#   ObjectId('6650a66d459b3818bfd79069'),
#   ObjectId('6650a66d459b3818bfd7906a'),
#   ObjectId('6650a66d459b3818bfd7906b'),
#   ObjectId('6650a66d459b3818bfd7906c'),
#   ObjectId('6650a66d459b3818bfd7906d'),
#   ObjectId('6650a66d459b3818bfd7906e'),
#   ObjectId('6650a66d459b3818bfd7906f'),
#   ObjectId('6650a66d459b3818bfd79070'),
#   ObjectId('6650a66d459b3818bfd79071'),
#   ObjectId('6650a66d459b3818bfd79072'),
#   ObjectId('6650a66d459b3818bfd79073'),
#   ObjectId('6650a66d459b3818bfd79074'),
#   ObjectId('6650a66d459b3818bfd79075'),
#   ObjectId('6650a66d459b3818bfd79076'),
#   ObjectId('6650a66d459b3818bfd79077'),
#   ObjectId('6650a66d459b3818bfd79078'),
#   ObjectId('6650a66d459b3818bfd79079'),
#   ObjectId('6650a66d459b3818bfd7907a'),
#   ObjectId('6650a66d459b3818bfd7907b'),
#   ObjectId('6650a66d459b3818bfd7907c'),
#   ObjectId('6650a66d459b3818bfd7907d'),
#   ObjectId('6650a66d459b3818bfd7907e'),
#   ObjectId('6650a66d459b3818bfd7907f'),
#   ObjectId('6650a66d459b3818bfd79080'),
#   ObjectId('6650a66d459b3818bfd79081'),
#   ObjectId('6650a66d459b3818bfd79082'),
#   ObjectId('6650a66d459b3818bfd79083'),
#   ObjectId('6650a66d459b3818bfd79084'),
#   ObjectId('6650a66d459b3818bfd79085'),
#   ObjectId('6650a66d459b3818bfd79086'),
#   ObjectId('6650a66d459b3818bfd79087'),
#   ObjectId('6650a66d459b3818bfd79088'),
#   ObjectId('6650a66d459b3818bfd79089'),
#   ObjectId('6650a66d459b3818bfd7908a'),
#   ObjectId('6650a66d459b3818bfd7908b'),
#   ObjectId('6650a66d459b3818bfd7908c'),
#   ObjectId('6650a66d459b3818bfd7908d'),
#   ObjectId('6650a66d459b3818bfd7908e'),
#   ObjectId('6650a66d459b3818bfd7908f'),
#   ObjectId('6650a66d459b3818bfd79090'),
#   ObjectId('6650a66d459b3818bfd79091'),
#   ObjectId('6650a66d459b3818bfd79092'),
#   ObjectId('6650a66d459b3818bfd79093'),
#   ObjectId('6650a66d459b3818bfd79094'),
#   ObjectId('6650a66d459b3818bfd79095'),
#   ObjectId('6650a66d459b3818bfd79096'),
#   ObjectId('6650a66d459b3818bfd79097'),
#   ObjectId('6650a66d459b3818bfd79098'),
#   ObjectId('6650a66d459b3818bfd79099'),
#   ObjectId('6650a66d459b3818bfd7909a'),
#   ObjectId('6650a66d459b3818bfd7909b'),
#   ObjectId('6650a66d459b3818bfd7909c'),
#   ObjectId('6650a66d459b3818bfd7909d'),
#   ObjectId('6650a66d459b3818bfd7909e'),
#   ObjectId('6650a66d459b3818bfd7909f'),
#   ObjectId('6650a66d459b3818bfd790a0'),
#   ObjectId('6650a66d459b3818bfd790a1'),
#   ObjectId('6650a66d459b3818bfd790a2'),
#   ObjectId('6650a66d459b3818bfd790a3'),
#   ObjectId('6650a66d459b3818bfd790a4'),
#   ObjectId('6650a66d459b3818bfd790a5'),
#   ObjectId('6650a66d459b3818bfd790a6'),
#   ObjectId('6650a66d459b3818bfd790a7'),
#   ObjectId('6650a66d459b3818bfd790a8'),
#   ObjectId('6650a66d459b3818bfd790a9'),
#   ObjectId('6650a66d459b3818bfd790aa'),
#   ObjectId('6650a66d459b3818bfd790ab'),
#   ObjectId('6650a66d459b3818bfd790ac'),
#   ObjectId('6650a66d459b3818bfd790ad'),
#   ObjectId('6650a66d459b3818bfd790ae'),
#   ObjectId('6650a66d459b3818bfd790af'),
#   ObjectId('6650a66d459b3818bfd790b0'),
#   ObjectId('6650a66d459b3818bfd790b1'),
#   ObjectId('6650a66d459b3818bfd790b2'),
#   ObjectId('6650a66d459b3818bfd790b3'),
#   ObjectId('6650a66d459b3818bfd790b4'),
#   ObjectId('6650a66d459b3818bfd790b5'),
#   ObjectId('6650a66d459b3818bfd790b6'),
#   ObjectId('6650a66d459b3818bfd790b7'),
#   ObjectId('6650a66d459b3818bfd790b8'),
#   ObjectId('6650a66d459b3818bfd790b9'),
#   ObjectId('6650a66d459b3818bfd790ba'),
#   ObjectId('6650a66d459b3818bfd790bb'),
#   ObjectId('6650a66d459b3818bfd790bc'),
#   ObjectId('6650a66d459b3818bfd790bd'),
#   ObjectId('6650a66d459b3818bfd790be'),
#   ObjectId('6650a66d459b3818bfd790bf'),
#   ObjectId('6650a66d459b3818bfd790c0'),
#   ObjectId('6650a66d459b3818bfd790c1'),
#   ObjectId('6650a66d459b3818bfd790c2'),
#   ObjectId('6650a66d459b3818bfd790c3'),
#   ObjectId('6650a66d459b3818bfd790c4'),
#   ObjectId('6650a66d459b3818bfd790c5'),
#   ObjectId('6650a66d459b3818bfd790c6'),
#   ObjectId('6650a66d459b3818bfd790c7'),
#   ObjectId('6650a66d459b3818bfd790c8'),
#   ObjectId('6650a66d459b3818bfd790c9'),
#   ObjectId('6650a66d459b3818bfd790ca'),
#   ObjectId('6650a66d459b3818bfd790cb'),
#   ObjectId('6650a66d459b3818bfd790cc'),
#   ObjectId('6650a66d459b3818bfd790cd'),
#   ObjectId('6650a66d459b3818bfd790ce'),
#   ObjectId('6650a66d459b3818bfd790cf'),
#   ObjectId('6650a66d459b3818bfd790d0'),
#   ObjectId('6650a66d459b3818bfd790d1'),
#   ObjectId('6650a66d459b3818bfd790d2'),
#   ObjectId('6650a66d459b3818bfd790d3'),
#   ObjectId('6650a66d459b3818bfd790d4'),
#   ObjectId('6650a66d459b3818bfd790d5'),
#   ObjectId('6650a66d459b3818bfd790d6'),
#   ObjectId('6650a66d459b3818bfd790d7'),
#   ObjectId('6650a66d459b3818bfd790d8'),
#   ObjectId('6650a66d459b3818bfd790d9'),
#   ObjectId('6650a66d459b3818bfd790da'),
#   ObjectId('6650a66d459b3818bfd790db'),
#   ObjectId('6650a66d459b3818bfd790dc'),
#   ObjectId('6650a66d459b3818bfd790dd'),
#   ObjectId('6650a66d459b3818bfd790de'),
#   ObjectId('6650a66d459b3818bfd790df'),
#   ObjectId('6650a66d459b3818bfd790e0'),
#   ObjectId('6650a66d459b3818bfd790e1'),
#   ObjectId('6650a66d459b3818bfd790e2'),
#   ObjectId('6650a66d459b3818bfd790e3'),
#   ObjectId('6650a66d459b3818bfd790e4'),
#   ObjectId('6650a66d459b3818bfd790e5'),
#   ObjectId('6650a66d459b3818bfd790e6'),
#   ObjectId('6650a66d459b3818bfd790e7'),
#   ObjectId('6650a66d459b3818bfd790e8'),
#   ObjectId('6650a66d459b3818bfd790e9'),
#   ObjectId('6650a66d459b3818bfd790ea'),
#   ObjectId('6650a66d459b3818bfd790eb'),
#   ObjectId('6650a66d459b3818bfd790ec'),
#   ObjectId('6650a66d459b3818bfd790ed'),
#   ObjectId('6650a66d459b3818bfd790ee'),
#   ObjectId('6650a66d459b3818bfd790ef'),
#   ObjectId('6650a66d459b3818bfd790f0'),
#   ObjectId('6650a66d459b3818bfd790f1'),
#   ObjectId('6650a66d459b3818bfd790f2'),
#   ObjectId('6650a66d459b3818bfd790f3'),
#   ObjectId('6650a66d459b3818bfd790f4'),
#   ObjectId('6650a66d459b3818bfd790f5'),
#   ObjectId('6650a66d459b3818bfd790f6'),
#   ObjectId('6650a66d459b3818bfd790f7'),
#   ObjectId('6650a66d459b3818bfd790f8'),
#   ObjectId('6650a66d459b3818bfd790f9'),
#   ObjectId('6650a66d459b3818bfd790fa'),
#   ObjectId('6650a66d459b3818bfd790fb'),
#   ObjectId('6650a66d459b3818bfd790fc'),
#   ObjectId('6650a66d459b3818bfd790fd'),
#   ObjectId('6650a66d459b3818bfd790fe'),
#   ObjectId('6650a66d459b3818bfd790ff'),
#   ObjectId('6650a66d459b3818bfd79100'),
#   ObjectId('6650a66d459b3818bfd79101'),
#   ObjectId('6650a66d459b3818bfd79102'),
#   ObjectId('6650a66d459b3818bfd79103'),
#   ObjectId('6650a66d459b3818bfd79104'),
#   ObjectId('6650a66d459b3818bfd79105'),
#   ObjectId('6650a66d459b3818bfd79106'),
#   ObjectId('6650a66d459b3818bfd79107'),
#   ObjectId('6650a66d459b3818bfd79108'),
#   ObjectId('6650a66d459b3818bfd79109'),
#   ObjectId('6650a66d459b3818bfd7910a'),
#   ObjectId('6650a66d459b3818bfd7910b'),
#   ObjectId('6650a66d459b3818bfd7910c'),
#   ObjectId('6650a66d459b3818bfd7910d'),
#   ObjectId('6650a66d459b3818bfd7910e'),
#   ObjectId('6650a66d459b3818bfd7910f'),
#   ObjectId('6650a66d459b3818bfd79110'),
#   ObjectId('6650a66d459b3818bfd79111'),
#   ObjectId('6650a66d459b3818bfd79112'),
#   ObjectId('6650a66d459b3818bfd79113'),
#   ObjectId('6650a66d459b3818bfd79114'),
#   ObjectId('6650a66d459b3818bfd79115'),
#   ObjectId('6650a66d459b3818bfd79116'),
#   ObjectId('6650a66d459b3818bfd79117'),
#   ObjectId('6650a66d459b3818bfd79118'),
#   ObjectId('6650a66d459b3818bfd79119'),
#   ObjectId('6650a66d459b3818bfd7911a'),
#   ObjectId('6650a66d459b3818bfd7911b'),
#   ObjectId('6650a66d459b3818bfd7911c'),
#   ObjectId('6650a66d459b3818bfd7911d'),
#   ObjectId('6650a66d459b3818bfd7911e'),
#   ObjectId('6650a66d459b3818bfd7911f'),
#   ObjectId('6650a66d459b3818bfd79120'),
#   ObjectId('6650a66d459b3818bfd79121'),
#   ObjectId('6650a66d459b3818bfd79122'),
#   ObjectId('6650a66d459b3818bfd79123'),
#   ObjectId('6650a66d459b3818bfd79124'),
#   ObjectId('6650a66d459b3818bfd79125'),
#   ObjectId('6650a66d459b3818bfd79126'),
#   ObjectId('6650a66d459b3818bfd79127'),
#   ObjectId('6650a66d459b3818bfd79128'),
#   ObjectId('6650a66d459b3818bfd79129'),
#   ObjectId('6650a66d459b3818bfd7912a'),
#   ObjectId('6650a66d459b3818bfd7912b'),
#   ObjectId('6650a66d459b3818bfd7912c'),
#   ObjectId('6650a66d459b3818bfd7912d'),
#   ObjectId('6650a66d459b3818bfd7912e'),
#   ObjectId('6650a66d459b3818bfd7912f'),
#   ObjectId('6650a66d459b3818bfd79130'),
#   ObjectId('6650a66d459b3818bfd79131'),
#   ObjectId('6650a66d459b3818bfd79132'),
#   ObjectId('6650a66d459b3818bfd79133'),
#   ObjectId('6650a66d459b3818bfd79134'),
#   ObjectId('6650a66d459b3818bfd79135'),
#   ObjectId('6650a66d459b3818bfd79136'),
#   ObjectId('6650a66d459b3818bfd79137'),
#   ObjectId('6650a66d459b3818bfd79138'),
#   ObjectId('6650a66d459b3818bfd79139'),
#   ObjectId('6650a66d459b3818bfd7913a'),
#   ObjectId('6650a66d459b3818bfd7913b'),
#   ObjectId('6650a66d459b3818bfd7913c'),
#   ObjectId('6650a66d459b3818bfd7913d'),
#   ObjectId('6650a66d459b3818bfd7913e'),
#   ObjectId('6650a66d459b3818bfd7913f'),
#   ObjectId('6650a66d459b3818bfd79140'),
#   ObjectId('6650a66d459b3818bfd79141'),
#   ObjectId('6650a66d459b3818bfd79142'),
#   ObjectId('6650a66d459b3818bfd79143'),
#   ObjectId('6650a66d459b3818bfd79144'),
#   ObjectId('6650a66d459b3818bfd79145'),
#   ObjectId('6650a66d459b3818bfd79146'),
#   ObjectId('6650a66d459b3818bfd79147'),
#   ObjectId('6650a66d459b3818bfd79148'),
#   ObjectId('6650a66d459b3818bfd79149'),
#   ObjectId('6650a66d459b3818bfd7914a'),
#   ObjectId('6650a66d459b3818bfd7914b'),
#   ObjectId('6650a66d459b3818bfd7914c'),
#   ObjectId('6650a66d459b3818bfd7914d'),
#   ObjectId('6650a66d459b3818bfd7914e'),
#   ObjectId('6650a66d459b3818bfd7914f'),
#   ObjectId('6650a66d459b3818bfd79150'),
#   ObjectId('6650a66d459b3818bfd79151'),
#   ObjectId('6650a66d459b3818bfd79152'),
#   ObjectId('6650a66d459b3818bfd79153'),
#   ObjectId('6650a66d459b3818bfd79154'),
#   ObjectId('6650a66d459b3818bfd79155'),
#   ObjectId('6650a66d459b3818bfd79156'),
#   ObjectId('6650a66d459b3818bfd79157'),
#   ObjectId('6650a66d459b3818bfd79158'),
#   ObjectId('6650a66d459b3818bfd79159'),
#   ObjectId('6650a66d459b3818bfd7915a'),
#   ObjectId('6650a66d459b3818bfd7915b'),
#   ObjectId('6650a66d459b3818bfd7915c'),
#   ObjectId('6650a66d459b3818bfd7915d'),
#   ObjectId('6650a66d459b3818bfd7915e'),
#   ObjectId('6650a66d459b3818bfd7915f'),
#   ObjectId('6650a66d459b3818bfd79160'),
#   ObjectId('6650a66d459b3818bfd79161'),
#   ObjectId('6650a66d459b3818bfd79162'),
#   ObjectId('6650a66d459b3818bfd79163'),
#   ObjectId('6650a66d459b3818bfd79164'),
#   ObjectId('6650a66d459b3818bfd79165'),
#   ObjectId('6650a66d459b3818bfd79166'),
#   ObjectId('6650a66d459b3818bfd79167'),
#   ObjectId('6650a66d459b3818bfd79168'),
#   ObjectId('6650a66d459b3818bfd79169'),
#   ObjectId('6650a66d459b3818bfd7916a'),
#   ObjectId('6650a66d459b3818bfd7916b'),
#   ObjectId('6650a66d459b3818bfd7916c'),
#   ObjectId('6650a66d459b3818bfd7916d'),
#   ObjectId('6650a66d459b3818bfd7916e'),
#   ObjectId('6650a66d459b3818bfd7916f'),
#   ObjectId('6650a66d459b3818bfd79170'),
#   ObjectId('6650a66d459b3818bfd79171'),
#   ObjectId('6650a66d459b3818bfd79172'),
#   ObjectId('6650a66d459b3818bfd79173'),
#   ObjectId('6650a66d459b3818bfd79174'),
#   ObjectId('6650a66d459b3818bfd79175'),
#   ObjectId('6650a66d459b3818bfd79176'),
#   ObjectId('6650a66d459b3818bfd79177'),
#   ObjectId('6650a66d459b3818bfd79178'),
#   ObjectId('6650a66d459b3818bfd79179'),
#   ObjectId('6650a66d459b3818bfd7917a'),
#   ObjectId('6650a66d459b3818bfd7917b'),
#   ObjectId('6650a66d459b3818bfd7917c'),
#   ObjectId('6650a66d459b3818bfd7917d'),
#   ObjectId('6650a66d459b3818bfd7917e'),
#   ObjectId('6650a66d459b3818bfd7917f'),
#   ObjectId('6650a66d459b3818bfd79180'),
#   ObjectId('6650a66d459b3818bfd79181'),
#   ObjectId('6650a66d459b3818bfd79182'),
#   ObjectId('6650a66d459b3818bfd79183'),
#   ObjectId('6650a66d459b3818bfd79184'),
#   ObjectId('6650a66d459b3818bfd79185'),
#   ObjectId('6650a66d459b3818bfd79186'),
#   ObjectId('6650a66d459b3818bfd79187'),
#   ObjectId('6650a66d459b3818bfd79188'),
#   ObjectId('6650a66d459b3818bfd79189'),
#   ObjectId('6650a66d459b3818bfd7918a'),
#   ObjectId('6650a66d459b3818bfd7918b'),
#   ObjectId('6650a66d459b3818bfd7918c'),
#   ObjectId('6650a66d459b3818bfd7918d'),
#   ObjectId('6650a66d459b3818bfd7918e'),
#   ObjectId('6650a66d459b3818bfd7918f'),
#   ObjectId('6650a66d459b3818bfd79190'),
#   ObjectId('6650a66d459b3818bfd79191'),
#   ObjectId('6650a66d459b3818bfd79192'),
#   ObjectId('6650a66d459b3818bfd79193'),
#   ObjectId('6650a66d459b3818bfd79194'),
#   ObjectId('6650a66d459b3818bfd79195'),
#   ObjectId('6650a66d459b3818bfd79196'),
#   ObjectId('6650a66d459b3818bfd79197'),
#   ObjectId('6650a66d459b3818bfd79198'),
#   ObjectId('6650a66d459b3818bfd79199'),
#   ObjectId('6650a66d459b3818bfd7919a'),
#   ObjectId('6650a66d459b3818bfd7919b'),
#   ObjectId('6650a66d459b3818bfd7919c'),
#   ObjectId('6650a66d459b3818bfd7919d'),
#   ObjectId('6650a66d459b3818bfd7919e'),
#   ObjectId('6650a66d459b3818bfd7919f'),
#   ObjectId('6650a66d459b3818bfd791a0'),
#   ObjectId('6650a66d459b3818bfd791a1'),
#   ObjectId('6650a66d459b3818bfd791a2'),
#   ObjectId('6650a66d459b3818bfd791a3'),
#   ObjectId('6650a66d459b3818bfd791a4'),
#   ObjectId('6650a66d459b3818bfd791a5'),
#   ObjectId('6650a66d459b3818bfd791a6'),
#   ObjectId('6650a66d459b3818bfd791a7'),
#   ObjectId('6650a66d459b3818bfd791a8'),
#   ObjectId('6650a66d459b3818bfd791a9'),
#   ObjectId('6650a66d459b3818bfd791aa'),
#   ObjectId('6650a66d459b3818bfd791ab'),
#   ObjectId('6650a66d459b3818bfd791ac'),
#   ObjectId('6650a66d459b3818bfd791ad'),
#   ObjectId('6650a66d459b3818bfd791ae'),
#   ObjectId('6650a66d459b3818bfd791af'),
#   ObjectId('6650a66d459b3818bfd791b0'),
#   ObjectId('6650a66d459b3818bfd791b1'),
#   ObjectId('6650a66d459b3818bfd791b2'),
#   ObjectId('6650a66d459b3818bfd791b3'),
#   ObjectId('6650a66d459b3818bfd791b4'),
#   ObjectId('6650a66d459b3818bfd791b5'),
#   ObjectId('6650a66d459b3818bfd791b6'),
#   ObjectId('6650a66d459b3818bfd791b7'),
#   ObjectId('6650a66d459b3818bfd791b8'),
#   ObjectId('6650a66d459b3818bfd791b9'),
#   ObjectId('6650a66d459b3818bfd791ba'),
#   ObjectId('6650a66d459b3818bfd791bb'),
#   ObjectId('6650a66d459b3818bfd791bc'),
#   ObjectId('6650a66d459b3818bfd791bd'),
#   ObjectId('6650a66d459b3818bfd791be'),
#   ObjectId('6650a66d459b3818bfd791bf'),
#   ObjectId('6650a66d459b3818bfd791c0'),
#   ObjectId('6650a66d459b3818bfd791c1'),
#   ObjectId('6650a66d459b3818bfd791c2'),
#   ObjectId('6650a66d459b3818bfd791c3'),
#   ObjectId('6650a66d459b3818bfd791c4')],
#  TaskWorkflow(database=<superduper.base.datalayer.Datalayer object at 0x14e166450>, G=<networkx.classes.digraph.DiGraph object at 0x1522329d0>))

# %% [markdown]
# Now that the images and their classes are inserted into the database, we can query the data in its original format. Particularly, we can use the `PIL.Image` instances to inspect the data.

# %%
# Get and display one of the images
r = db['mnist'].find_one().execute()
r.unpack()['img'].resize((300, 300))
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %% [markdown]
# ## Build Model

# %% [markdown]
# Following that, we build our machine learning model.  conveniently supports various frameworks, and for this example, we opt for PyTorch, a suitable choice for computer vision tasks. In this instance, we combine `torch` with `torchvision`.
#
# To facilitate communication with the  `Datalayer`, we design `postprocess` and `preprocess` functions. These functions are then encapsulated with the model, preprocessing, and postprocessing steps to create a native  handler.

# %%
from superduper.ext.torch import TorchModel

import torch

# Define the LeNet-5 architecture for image classification
class LeNet5(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        # Layer 1
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(1, 6, kernel_size=5, stride=1, padding=0),
            torch.nn.BatchNorm2d(6),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2))
        # Layer 2
        self.layer2 = torch.nn.Sequential(
            torch.nn.Conv2d(6, 16, kernel_size=5, stride=1, padding=0),
            torch.nn.BatchNorm2d(16),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2))
        # Fully connected layers
        self.fc = torch.nn.Linear(400, 120)
        self.relu = torch.nn.ReLU()
        self.fc1 = torch.nn.Linear(120, 84)
        self.relu1 = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(84, num_classes)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.relu(out)
        out = self.fc1(out)
        out = self.relu1(out)
        out = self.fc2(out)
        return out

# Postprocess function for the model output    
def postprocess(x):
    return int(x.topk(1)[1].item())

# Preprocess function for input data
def preprocess(x):
    return torchvision.transforms.Compose([
        torchvision.transforms.Resize((32, 32)),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(mean=(0.1307,), std=(0.3081,))]
    )(x)

# Create an instance of the LeNet-5 model
lenet_model = LeNet5(10)


model = TorchModel(
    identifier='my-model',
    object=lenet_model,
    preprocess=preprocess,
    postprocess=postprocess, 
    preferred_devices=('cpu',),
)

# Check that the model successfully creates predictions over single data-points
model.predict_one(data[0]['img'])
# Out:
# 2024-May-24 16:38:43.57| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:386  | Initializing TorchModel : my-model
# 2024-May-24 16:38:43.57| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:389  | Initialized  TorchModel : my-model successfully
# 1

# %% [markdown]
# ## Train Model
#
# Now we are ready to "train" or "fit" the model. Trainable models in  come with a sklearn-like `.fit` method,
# which developers may implement for their specific model class. `torch` models come with a pre-configured
# `TorchTrainer` class and `.fit` method. These may be invoked simply by "applying" the model to `db`:

# %%
from torch.nn.functional import cross_entropy

from superduper import Metric, Validation, Dataset
from superduper.ext.torch import TorchTrainer

acc = lambda x, y: (sum([xx == yy for xx, yy in zip(x, y)]) / len(x))

accuracy = Metric(identifier='acc', object=acc)

model.validation = Validation(
    'mnist_performance',
    datasets=[
        Dataset(
            identifier='my-valid',
            select=db['mnist'].find({'_fold': 'valid'})
        )
    ],
    metrics=[accuracy],
)

model.trainer = TorchTrainer(
    identifier='my-trainer',
    objective=cross_entropy,
    loader_kwargs={'batch_size': 10},
    max_iterations=1000,
    validation_interval=5,
    select=db['mnist'].find(),
    key=('img', 'class'),
    transform=lambda x, y: (preprocess(x), y),
)

_ = db.apply(model)
# Out:
# 2024-May-24 16:38:48.40| WARNING  | Duncans-MacBook-Pro.fritz.box| superduper.backends.local.artifacts:82   | File /tmp/a10fbf2cdd7532dd7bf5bba03b7c28e01b4326cc already exists
# 2024-May-24 16:38:48.43| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.backends.local.compute:37   | Submitting job. function:<function method_job at 0x10c3fdd00>
# 2024-May-24 16:38:48.55| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.ext.torch.training:221  | fold: TRAIN; iteration: 0; objective: 2.3169732093811035;
# 2024-May-24 16:38:48.57| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:386  | Initializing Dataset : my-valid
# 2024-May-24 16:38:48.58| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:389  | Initialized  Dataset : my-valid successfully
# 2024-May-24 16:38:48.58| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:386  | Initializing TorchModel : my-model
# 2024-May-24 16:38:48.58| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.components.component:389  | Initialized  TorchModel : my-model successfully
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:00<00:00, 823.29it/s]
# 2024-May-24 16:38:48.64| INFO     | Duncans-MacBook-Pro.fritz.box| superduper.ext.torch.training:221  | fold: VALID; iteration: 0; acc: 0.10638297872340426; objective: 2.29463472366333;
# > /Users/dodo//superduper/superduper/ext/torch/training.py(165)_fit_with_dataloaders()
#     163                         db.replace(model, upsert=True)
#     164                         import pdb; pdb.set_trace()
# --> 165                         self.changed.update({'all_metrics', 'optimizer_state'})
#     166                     stop = self.stopping_criterion(iteration)
#     167                     if stop:
# ipdb>  !model.trainer.metric_values
# {'acc': [0.10638297872340426], 'objective': [2.29463472366333]}
# ipdb>  q

# %%
from matplotlib import pyplot as plt

# Load the model from the database
model = db.load('model', model.identifier)

# Plot the accuracy values
plt.plot(model.trainer.metric_values['my-valid/acc'])
plt.show()
